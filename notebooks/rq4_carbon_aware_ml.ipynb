# %% [markdown]
# # RQ4 - Carbon-Aware ML Analysis
#
# **Research question.** Can an interpretable low-complexity model explain the dominant drivers of high-load risk without a large loss in predictive utility?
#
# This notebook is intentionally reproducible: it reads the raw `data.csv` if `preprocessed_content.csv` is absent, rebuilds the engineered dataset, and writes the publication-ready table and figure for RQ4.
#
# Methodological steps:
#
# 1. Load the Germany-relevant OPSD hourly time-series variables.
# 2. Construct a next-day high-load target.
# 3. Use chronological evaluation: 2015-2018 for training and 2019-2020 for testing.
# 4. Save the result table as `outputs/tables/rq4_top_interpretable_features.csv`.
# 5. Save the figure as `outputs/figures/rq4_interpretability_efficiency.pdf` and a PNG companion for the report.

# %%
import os
import sys
from pathlib import Path

import pandas as pd
from IPython.display import Image, display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from scripts import generate_analysis_assets as assets

df = assets.load_or_create_preprocessed()
result = assets.run_rq4(df)

# Display saved artifacts in the executed notebook for GitHub review.
table_dir = PROJECT_ROOT / "outputs" / "tables"
figure_dir = PROJECT_ROOT / "outputs" / "figures"
table_path = table_dir / "rq4_top_interpretable_features.csv"
figure_path = figure_dir / "rq4_interpretability_efficiency.png"
pdf_path = figure_dir / "rq4_interpretability_efficiency.pdf"
display(pd.read_csv(table_path).head())
display(Image(filename=str(figure_path)))
print(f"Saved table: {table_path.relative_to(PROJECT_ROOT)}")
print(f"Saved PDF figure: {pdf_path.relative_to(PROJECT_ROOT)}")
# Out:
#                feature           display_feature  \
# 0   load_roll_24h_mean   Load rolling mean, 24 h
# 1              dow_sin          Day-of-week sine
# 2           is_weekend         Weekend indicator
# 3  load_roll_168h_mean  Load rolling mean, 168 h
# 4  zone_tennet_load_mw          TenneT zone load
#
#    standardized_logit_coefficient  absolute_coefficient  \
# 0                       -3.536931              3.536931
# 1                        2.542970              2.542970
# 2                        1.635670              1.635670
# 3                        1.603101              1.603101
# 4                        1.492930              1.492930
#
#    permutation_importance_mean  permutation_importance_std       direction  \
# 0                     0.168416                    0.007679  decreases risk
# 1                     0.231055                    0.010504  increases risk
# 2                     0.072529                    0.009026  increases risk
# 3                     0.197074                    0.009372  increases risk
# 4                     0.103543                    0.011209  increases risk
#
#                                domain_interpretation
# 0  Higher current or lagged load reduces next-day...
# 1  Calendar structure raises high-load risk for r...
# 2  Calendar structure raises high-load risk for r...
# 3  Higher current or lagged load raises next-day ...
# 4  Higher current or lagged load raises next-day ...
# Saved table: outputs/tables/rq4_top_interpretable_features.csv
# Saved PDF figure: outputs/figures/rq4_interpretability_efficiency.pdf
